# %%
noun1=input("noun(Name 0f Place i.e. Zoo): ")
verb1=input("verb(i.e. go/walk): ")
pronoun=input("pronoun(i.e. it/that): ")
verb2=input("verb(about noun2 i.e Good/funy): ")
noun2=input("noun(Name of animal i.e Monkey): ")
noun3=input("noun: ")
verb3=input("verb: ")
pron=input("pronoun: ")
adj1=input("adjective: ")
adj2=input("adjective: ")
adj3=input("adjective: ")

madlib = (f"""Today I {verb1} to a {noun1} where I saw a {noun2} who was {verb2} some delicious {noun3}.
I {verb3} 4 different flavour of {pronoun}.Two of them tastes the {adj1},
one was {adj2} and the fourth one tastes the {adj3}.""")

print(madlib)
# Out:
# noun: noddles
# verb: working
# pronoun: me
# verb: die
# noun: book
# noun: charger
# verb: bpoking
# pronoun: them
# adjective: beautiful
# adjective: tasty
# adjective: worst
# Today I working to a noddles where I saw a book who was die some delicious charger.
# I bpoking 4 different flavour of them.Two of them tastes the beautiful,
# one was tasty and the fourth one tastes the worst.
